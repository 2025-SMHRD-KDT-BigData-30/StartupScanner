# %%
import os
import pandas as pd

# 폴더 경로
folder_path = 'C:/Users/smhrd/Desktop/부동산'

# 폴더 내 모든 .csv 파일 경로 리스트 생성
csv_files = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.csv')]

# 모든 csv 파일을 읽어서 DataFrame 리스트 생성
df_list = [pd.read_csv(file) for file in csv_files]

# DataFrame 모두 합치기
df_all = pd.concat(df_list, ignore_index=True)

# %%
df_all = df_all.drop(columns=['현재업종', '준공인가일', '권리금', '매물특징', '입주가능일', '해당층/총층'], errors='ignore')

# %%
df_all['소재지'] = df_all['소재지'].str.replace('광주시 서구 ', '', regex=False)

# %%
df_all[df_all['추천업종'] == "-"]
df_all[df_all['추천업종'].isna()]
# Out:
#              제목              월세  소재지                  계약/전용면적 추천업종  \
# 2       대형사무실2층        월세1억/800  마륵동   339.3㎡/339.3㎡(전용률100%)  NaN
# 7       대형사무실2층     월세5,000/450  마륵동       330㎡/330㎡(전용률100%)  NaN
# 13     중소형사무실3층     월세4,000/200  마륵동  132.23㎡/112.39㎡(전용률85%)  NaN
# 19      대형사무실2층  월세1억 4,000/700  마륵동  387.24㎡/332.92㎡(전용률86%)  NaN
# 25     중소형사무실3층     월세1,000/100  치평동     111㎡/109.09㎡(전용률98%)  NaN
# ...         ...             ...  ...                      ...  ...
# 2732  상가건물B1~4층     월세3,000/190  마륵동                      NaN  NaN
# 2740   중소형사무실2층        월세500/40  마륵동       131.2㎡/33㎡(전용률25%)  NaN
# 2744    대형사무실2층  월세1억 4,000/700  마륵동  387.24㎡/332.92㎡(전용률86%)  NaN
# 2748   중소형사무실3층     월세2,000/150  마륵동         96㎡/96㎡(전용률100%)  NaN
# 2749   중소형사무실2층     월세3,000/140  마륵동   115.7㎡/115.7㎡(전용률100%)  NaN
#
#             매물번호         위도          경도
# 2     2519082382  35.140963  126.828657
# 7     2519079341  35.141365  126.829046
# 13    2518233616  35.142021  126.831358
# 19    2517785721  35.142079  126.832159
# 25    2519915711  35.143140  126.833798
# ...          ...        ...         ...
# 2732  2519002572  35.145706  126.854867
# 2740  2514338208  35.146055  126.854831
# 2744  2517785721  35.144543  126.850956
# 2748  2515481762  35.144542  126.854825
# 2749  2514167351  35.144542  126.854825
#
# [620 rows x 8 columns]

# %%
df_all['추천업종'] = df_all['추천업종'].fillna('-')

# %%
df_all['소재지'].unique()
# Out:
# array(['마륵동', '치평동', '매월동', '쌍촌동', '양동', '유촌동', '풍암동', '광천동', '화정동',
#        '농성동', '금호동', '내방동', '광주시 남구 월산동', '동천동'], dtype=object)

# %%
df_all = df_all[df_all['소재지'] != '광주시 남구 월산동']

# %%
df_all['소재지'].unique()
# Out:
# array(['마륵동', '치평동', '매월동', '쌍촌동', '양동', '유촌동', '풍암동', '광천동', '화정동',
#        '농성동', '금호동', '내방동', '동천동'], dtype=object)

# %%
df_all['소재지'] = df_all['소재지'].replace({
    '유촌동': '유덕동',  # ❌ → 이건 반대
    '내방동': '화정동',  # ❌ → 이것도 반대
    '마륵동': '서창동',  # ✅ ← 이것만 맞음
    '매월동': '서창동'   # ✅
})

# %%
sorted_unique_values = sorted(df_all['소재지'].unique())
print(sorted_unique_values)
# Out:
# ['광천동', '금호동', '농성동', '동천동', '상무1동', '상무2동', '서창동', '양동', '유덕동', '치평동', '풍암동', '화정동']

# %%
df_all[df_all['소재지']=="쌍촌동"]
# Out:
#             제목           월세  소재지                   계약/전용면적               추천업종  \
# 39      일반상가1층  월세3,000/200  쌍촌동  112.19㎡/112.19㎡(전용률100%)                  -
# 40      일반상가1층  월세3,000/205  쌍촌동      112.19㎡/109㎡(전용률97%)                  -
# 41      일반상가1층  월세3,000/200  쌍촌동  112.19㎡/112.19㎡(전용률100%)  편의점 판매업 커피 디저트 한식
# 42      복합상가1층   월세1,000/80  쌍촌동    97.45㎡/97.45㎡(전용률100%)                  -
# 43    중소형사무실3층  월세1,500/100  쌍촌동    39.67㎡/39.67㎡(전용률100%)                  -
# ...        ...          ...  ...                       ...                ...
# 1992  중소형사무실2층  월세2,000/120  쌍촌동        97.63㎡/90㎡(전용률92%)                  -
# 1993    일반상가2층  월세2,000/119  쌍촌동    97.63㎡/97.63㎡(전용률100%)           사무실, 미용실
# 1994    일반상가2층  월세3,000/130  쌍촌동      97.63㎡/89.2㎡(전용률91%)                  -
# 1995   일반사무실3층   월세1,000/50  쌍촌동    82.05㎡/82.05㎡(전용률100%)                  -
# 2545  중소형사무실3층   월세1,000/85  쌍촌동      115.7㎡/99.1㎡(전용률86%)                  -
#
#             매물번호         위도          경도
# 39    2518249938  35.159547  126.857387
# 40    2516617794  35.159547  126.857387
# 41    2515656847  35.159547  126.857387
# 42    2513991060  35.159547  126.857387
# 43    2519354334  35.159554  126.857798
# ...          ...        ...         ...
# 1992  2519170570  35.150819  126.855938
# 1993  2517099239  35.150819  126.855938
# 1994  2513916518  35.150819  126.855938
# 1995  2517437083  35.150819  126.855938
# 2545  2516618196  35.152677  126.873073
#
# [436 rows x 8 columns]

# %%
import numpy as np

# 기준선: (위도, 경도) 순서로 두 점 정의 (예시값, 실제 경계에 맞게 수정 필요)
lat1, lon1 = 35.150003489023504, 126.8559765815735  # 기준선의 첫 번째 점
lat2, lon2 = 35.15224919419664,126.87131881713869  # 기준선의 두 번째 점

# 기준선의 직선식 계산 (Ax + By + C = 0)
A = lat2 - lat1
B = lon1 - lon2
C = lat1 * lon2 - lat2 * lon1

# 직선 기준으로 점이 위쪽(>0)이면 상무1동, 아래쪽(<0)이면 상무2동
def classify_sangmu(lat, lon):
    result = A * lon + B * lat + C
    return '상무1동' if result > 0 else '상무2동'

# 쌍촌동 데이터에 적용
mask = df_all['소재지'] == '쌍촌동'
df_all.loc[mask, '소재지'] = df_all.loc[mask].apply(
    lambda row: classify_sangmu(row['위도'], row['경도']), axis=1
)

# %%
import json
import folium

# 1. JSON 파일 열기
with open('C:/Users/smhrd/Desktop/seogu.geojson', 'r', encoding='utf-8') as f:
    geo_data = json.load(f)

# 4. folium 지도 생성
m = folium.Map(
    location=[35.1445, 126.9156],
    tiles='cartodbpositron',
    zoom_start=13,
    zoom_control=True,          # 줌 버튼 비활성화
    scrollWheelZoom=True,       # 마우스 휠 줌 비활성화
    dragging=True               # 드래그 이동 비활성화
)

# 5. GeoJson 추가 (툴팁에 동 이름 표시)
folium.GeoJson(
    geo_data,
    name='광주 서구 통합 동',
    tooltip=folium.GeoJsonTooltip(fields=['adm_nm'], aliases=['행정동:'])
).add_to(m)

# ['광천동', '금호동', '농성동', '동천동', '상무1동', '상무2동', '서창동', '양동', '유덕동', '치평동', '풍암동', '화정동']
sangmu1_data = df_all[df_all['소재지'] == '화정동']

for _, row in sangmu1_data.iterrows():
# for _, row in df_all.iterrows():
    latitude = row['위도']
    longitude = row['경도']
    
    # 마커 추가
    folium.Marker(
        location=[latitude, longitude],
        popup=f"{row['소재지']}",  # 클릭 시 표시될 텍스트
        icon=folium.Icon(color='blue')  # 마커 색상 (파란색)
    ).add_to(m)

# 7. LayerControl 추가 (GeoJson 레이어를 켜고 끌 수 있는 버튼)
folium.LayerControl().add_to(m)

# 8. 지도 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64dcd04eff2a3dab46b3fe79e32161ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64dcd04eff2a3dab46b3fe79e32161ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64dcd04eff2a3dab46b3fe79e32161ea = L.map(
#                 &quot;map_64dcd04eff2a3dab46b3fe79e32161ea&quot;,
#                 {
#                     center: [35.1445, 126.9156],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;scrollWheelZoom&quot;: true,
#   &quot;dragging&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4b52e0897473e5e7ed7a7b7d90bb8a6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4b52e0897473e5e7ed7a7b7d90bb8a6.addTo(map_64dcd04eff2a3dab46b3fe79e32161ea);
#
#
#
#         function geo_json_a4503ced8c55f3dbc7a1636e35c499b4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a4503ced8c55f3dbc7a1636e35c499b4 = L.geoJson(null, {
#                 onEachFeature: geo_json_a4503ced8c55f3dbc7a1636e35c499b4_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_a4503ced8c55f3dbc7a1636e35c499b4_add (data) {
#             geo_json_a4503ced8c55f3dbc7a1636e35c499b4
#                 .addData(data);
#         }
#             geo_json_a4503ced8c55f3dbc7a1636e35c499b4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.90221456989586, 35.155058498643754], [126.90727075351943, 35.15148714336995], [126.90997195600762, 35.148970114785236], [126.90550878270994, 35.14826976191251], [126.90535498113478, 35.148330943562044], [126.90440241633748, 35.14870995780059], [126.90414852203126, 35.14884927637311], [126.90369325665951, 35.14909910212269], [126.90318091374216, 35.14950873015448], [126.9030611861838, 35.149604532651324], [126.9009028016137, 35.152419274808835], [126.8987195784849, 35.152256762403795], [126.89727501927882, 35.1524454999888], [126.89647989627917, 35.15216465589112], [126.89580619117513, 35.153496125144365], [126.89591482514163, 35.15412849252181], [126.89588265473901, 35.15444669387844], [126.89554001476193, 35.15521639987599], [126.89370700944629, 35.15630926210216], [126.89310337715112, 35.157285813940106], [126.89158841721736, 35.15800650655138], [126.89082524873008, 35.15896052663561], [126.89073566167748, 35.159693477139726], [126.89037739411928, 35.159750449291515], [126.89031570932494, 35.160024419433945], [126.89067273628099, 35.16013396871189], [126.89053663609597, 35.16078959824249], [126.8918333647799, 35.16085244022633], [126.89277949900497, 35.160742086251894], [126.89572467635985, 35.15927765591414], [126.89827181733594, 35.15839892132779], [126.89953631937829, 35.157567659129484], [126.90221456989586, 35.155058498643754]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;adm_nm&quot;: &quot;\uc591\ub3d9&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.8945888650783, 35.15089256672375], [126.89338031218168, 35.15050854497149], [126.89331198985565, 35.15007229195921], [126.8921959132385, 35.14939568950494], [126.8901927058898, 35.149038947288496], [126.88699870127306, 35.14739186327889], [126.88652372414208, 35.147139422117796], [126.8855565597362, 35.1481034488804], [126.88457453983581, 35.1476411577004], [126.8814113033145, 35.150759813408534], [126.88073501803784, 35.15145630815224], [126.88161743653963, 35.15170783500039], [126.88132978809492, 35.15230472983193], [126.88120466077913, 35.152699294896145], [126.88376741837314, 35.15326896504928], [126.8829782568605, 35.158320711372774], [126.88302312983487, 35.15935339765143], [126.883466229359, 35.161277444809336], [126.8877370366594, 35.16111343465202], [126.88834249638563, 35.16149852652283], [126.88957235069664, 35.160934128284914], [126.89053663609597, 35.16078959824249], [126.89067273628099, 35.16013396871189], [126.89031570932494, 35.160024419433945], [126.89037739411928, 35.159750449291515], [126.89073566167748, 35.159693477139726], [126.89082524873008, 35.15896052663561], [126.89158841721736, 35.15800650655138], [126.89310337715112, 35.1572858

# %%
# '(전용률'이 포함되지 않은 행 필터링
# filtered_df = df_all[~df_all['계약/전용면적'].astype(str).str.contains('\(전용률')]
filtered_df = df_all[~df_all['계약/전용면적'].astype(str).str.contains(r'\(전용률')]

# 결과 출력 (원하는 컬럼만 보려면 예: ['계약/전용면적'])
print(filtered_df['계약/전용면적'].unique())
df_all['계약/전용면적'] = df_all['계약/전용면적'].fillna('-')
df_all[df_all['계약/전용면적'] != '-']
# Out:
# ['-']
#             제목                월세  소재지                   계약/전용면적          추천업종  \
# 0       일반상가1층       월세5,000/500  서창동    339.4㎡/339.4㎡(전용률100%)  베이커리 카페 레스토랑
# 1       일반상가2층          월세1억/300  서창동    264.4㎡/264.4㎡(전용률100%)             -
# 2      대형사무실2층          월세1억/800  서창동    339.3㎡/339.3㎡(전용률100%)             -
# 3       일반상가1층  월세1억 5,000/1,000  서창동  369.91㎡/369.91㎡(전용률100%)             -
# 4       일반상가1층       월세1,500/870  서창동      430㎡/369.91㎡(전용률86%)             -
# ...        ...               ...  ...                       ...           ...
# 2746    일반상가2층       월세7,000/350  서창동   193.62㎡/166.46㎡(전용률86%)     의원,학원,사무실
# 2747   일반상가B1층       월세3,000/120  서창동          93㎡/93㎡(전용률100%)   네일샵.도소매.옷가게
# 2748  중소형사무실3층       월세2,000/150  서창동          96㎡/96㎡(전용률100%)             -
# 2749  중소형사무실2층       월세3,000/140  서창동    115.7㎡/115.7㎡(전용률100%)             -
# 2750   단지내상가1층        월세1,000/40  서창동     67.76㎡/52.47㎡(전용률77%)             -
#
#             매물번호         위도          경도
# 0     2518649529  35.141114  126.827603
# 1     2519102976  35.140915  126.828333
# 2     2519082382  35.140963  126.828657
# 3     2515136275  35.141148  126.829303
# 4     2515614013  35.141148  126.829303
# ...          ...        ...         ...
# 2746  2517780754  35.144543  126.850956
# 2747  2519004846  35.145380  126.850126
# 2748  2515481762  35.144542  126.854825
# 2749  2514167351  35.144542  126.854825
# 2750  2516463729  35.145126  126.855806
#
# [2726 rows x 8 columns]

# %%
import re
df_all['계약/전용면적'] = df_all['계약/전용면적'].apply(
    lambda x: re.sub(r'\(.*?\)', '', x).strip() if pd.notna(x) and x != '-' else x
)
df_all
# Out:
#             제목                월세  소재지          계약/전용면적          추천업종  \
# 0       일반상가1층       월세5,000/500  서창동    339.4㎡/339.4㎡  베이커리 카페 레스토랑
# 1       일반상가2층          월세1억/300  서창동    264.4㎡/264.4㎡             -
# 2      대형사무실2층          월세1억/800  서창동    339.3㎡/339.3㎡             -
# 3       일반상가1층  월세1억 5,000/1,000  서창동  369.91㎡/369.91㎡             -
# 4       일반상가1층       월세1,500/870  서창동     430㎡/369.91㎡             -
# ...        ...               ...  ...              ...           ...
# 2746    일반상가2층       월세7,000/350  서창동  193.62㎡/166.46㎡     의원,학원,사무실
# 2747   일반상가B1층       월세3,000/120  서창동          93㎡/93㎡   네일샵.도소매.옷가게
# 2748  중소형사무실3층       월세2,000/150  서창동          96㎡/96㎡             -
# 2749  중소형사무실2층       월세3,000/140  서창동    115.7㎡/115.7㎡             -
# 2750   단지내상가1층        월세1,000/40  서창동    67.76㎡/52.47㎡             -
#
#             매물번호         위도          경도
# 0     2518649529  35.141114  126.827603
# 1     2519102976  35.140915  126.828333
# 2     2519082382  35.140963  126.828657
# 3     2515136275  35.141148  126.829303
# 4     2515614013  35.141148  126.829303
# ...          ...        ...         ...
# 2746  2517780754  35.144543  126.850956
# 2747  2519004846  35.145380  126.850126
# 2748  2515481762  35.144542  126.854825
# 2749  2514167351  35.144542  126.854825
# 2750  2516463729  35.145126  126.855806
#
# [2750 rows x 8 columns]

# %%
df_all['월세'] = df_all['월세'].astype(str).str.replace(r'^월세', '', regex=True).str.strip()
df_all
# Out:
#             제목              월세  소재지          계약/전용면적          추천업종  \
# 0       일반상가1층       5,000/500  서창동    339.4㎡/339.4㎡  베이커리 카페 레스토랑
# 1       일반상가2층          1억/300  서창동    264.4㎡/264.4㎡             -
# 2      대형사무실2층          1억/800  서창동    339.3㎡/339.3㎡             -
# 3       일반상가1층  1억 5,000/1,000  서창동  369.91㎡/369.91㎡             -
# 4       일반상가1층       1,500/870  서창동     430㎡/369.91㎡             -
# ...        ...             ...  ...              ...           ...
# 2746    일반상가2층       7,000/350  서창동  193.62㎡/166.46㎡     의원,학원,사무실
# 2747   일반상가B1층       3,000/120  서창동          93㎡/93㎡   네일샵.도소매.옷가게
# 2748  중소형사무실3층       2,000/150  서창동          96㎡/96㎡             -
# 2749  중소형사무실2층       3,000/140  서창동    115.7㎡/115.7㎡             -
# 2750   단지내상가1층        1,000/40  서창동    67.76㎡/52.47㎡             -
#
#             매물번호         위도          경도
# 0     2518649529  35.141114  126.827603
# 1     2519102976  35.140915  126.828333
# 2     2519082382  35.140963  126.828657
# 3     2515136275  35.141148  126.829303
# 4     2515614013  35.141148  126.829303
# ...          ...        ...         ...
# 2746  2517780754  35.144543  126.850956
# 2747  2519004846  35.145380  126.850126
# 2748  2515481762  35.144542  126.854825
# 2749  2514167351  35.144542  126.854825
# 2750  2516463729  35.145126  126.855806
#
# [2750 rows x 8 columns]

# %%
df_all.to_json('부동산.json', orient='records', force_ascii=False, indent=2)
